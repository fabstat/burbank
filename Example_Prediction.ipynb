# %%
import os
from data_preprocessing import *
from burbank import *

# %% [markdown]
# ### Prepare the datasets
#
# Process the xlsx and gather the GDD data
#
# ___

# %%
### Uncomment to get the GDD data if not yet obtained:
# scrape_website_data(station='KFLO', year=2024, start_month=4, start_day=21, end_month=8, end_day=31)
# scrape_website_data(station='ONTO', year=2024, start_month=4, start_day=21, end_month=8, end_day=31)
# scrape_website_data(station='HERO', year=2024, start_month=3, start_day=23, end_month=8, end_day=1)
# scrape_website_data(station='HERO', year=2024, start_month=4, start_day=21, end_month=8, end_day=31)
potatoes = process_xlsx_data('./xlsx_data/', 2024)
potatoes.to_csv(os.path.join('./input/', "potatoes.csv"))
gdd = make_gdd_dict()
gdd.to_csv(os.path.join('./input/', "gdd.csv"))
# Out:
# /home/fabiana/Documents/burbank_local/data_preprocessing.py:178: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, df21], axis=0)
# /home/fabiana/Documents/burbank_local/data_preprocessing.py:178: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, df21], axis=0)
# ...

# %% [markdown]
# ### Predict
#
# If there is a model file in the model folder, we can predict
#
# ----

# %%
input_df = load_preprocessed_data('./input/')
input_df.to_csv(os.path.join('./output/', "processed_potatoes.csv"))
predict(preprocessed_input=input_df, model_file_path='./model/svc.pkl', output_path='./output/')
# Out:
# Results dataframe saved to ./output/ as predictions.csv
#               Clone Trial Region  pred  prob of 0  prob of 1
# 0     Ranger Russet          ONT   0.0   0.977202   0.022798
# 1     Ranger Russet           KF   0.0   0.987026   0.012974
# 2     Ranger Russet    HER_Early   0.0   0.992857   0.007143
# 3     Ranger Russet     HER_Late   0.0   0.970266   0.029734
# 4    Russet Burbank          ONT   0.0   0.979507   0.020493
# ..              ...          ...   ...        ...        ...
# 130      OR18H018-1          ONT   0.0   0.965270   0.034730
# 131      OR18H018-1           KF   0.0   0.921158   0.078842
# 132      OR18H018-1    HER_Early   0.0   0.879069   0.120931
# 133      OR18H018-1     HER_Late   1.0   0.535441   0.464559
# 134         Shepody    HER_Early   0.0   0.993830   0.006170
#
# [135 rows x 5 columns]
